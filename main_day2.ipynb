# %%
# Enable env before running .\venv\Scripts\Activate
# Code for adding IDs for the players for each frame. The same player hasn't been assigned the same ID even after he leaves the frame yet. Re-ID will be done in day3
from tracker import Player, iou, compare_players
from ultralytics import YOLO
import cv2
import os
import json

# %%
VIDEO_PATH = "15sec_input_720p.mp4"
MODEL_PATH = "best.pt"
CROPS_DIR = "players_crops"
FRAMES_DIR = "detected_frames_day2"

# Create folders if they don't exist
os.makedirs(CROPS_DIR, exist_ok=True)
os.makedirs(FRAMES_DIR, exist_ok=True)

# Load YOLO model
model = YOLO(MODEL_PATH)

# Open video
cap = cv2.VideoCapture(VIDEO_PATH)

# Initialize tracking variables
player_id_counter = 0
active_players = []
frame_id = 0
tracking_output = []

# %%
while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)[0]
    detections = []

    # Get new player detections
    for i, box in enumerate(results.boxes):
        cls_id = int(box.cls[0])
        conf = float(box.conf[0])

        if model.names[cls_id] != "player" or conf < 0.5:
            continue

        x1, y1, x2, y2 = map(int, box.xyxy[0])
        crop = frame[y1:y2, x1:x2]

        detections.append({
            "bbox": [x1, y1, x2, y2],
            "crop": crop,
            "assigned": False
        })

    # Match new detections with existing players
    for det in detections:
        matched = False
        for player in active_players:
            if frame_id - player.last_seen > 5:
                continue  # ignore if player unseen for too long

            # Match based on IoU
            score = iou(det["bbox"], player.bbox)
            if score > 0.4:
                player.update(det["bbox"], frame_id, det["crop"])
                det["assigned"] = True
                matched = True
                tracking_output.append({
                    "frame": frame_id,
                    "id": player.id,
                    "bbox": det["bbox"]
                })
                break

        # Assign new ID if no match found
        if not matched:
            new_player = Player(player_id_counter, det["bbox"], frame_id, det["crop"])
            active_players.append(new_player)
            tracking_output.append({
                "frame": frame_id,
                "id": player_id_counter,
                "bbox": det["bbox"]
            })
            player_id_counter += 1

    # Draw IDs and save annotated frame
    for entry in tracking_output:
        if entry["frame"] == frame_id:
            x1, y1, x2, y2 = entry["bbox"]
            pid = entry["id"]
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, f'ID: {pid}', (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    frame_save_path = f"{FRAMES_DIR}/frame_{frame_id:03}.jpg"
    cv2.imwrite(frame_save_path, frame)
    print(f"✅ Processed frame {frame_id}")
    frame_id += 1

cap.release()
# Out:
# 0: 384x640 1 ball, 16 players, 2 referees, 18908.4ms
# Speed: 241.3ms preprocess, 18908.4ms inference, 61.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 0
#
# 0: 384x640 18 players, 2 referees, 21270.7ms
# Speed: 248.0ms preprocess, 21270.7ms inference, 102.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 1
#
# 0: 384x640 1 ball, 16 players, 2 referees, 17794.4ms
# Speed: 15.5ms preprocess, 17794.4ms inference, 77.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 2
#
# 0: 384x640 1 ball, 14 players, 2 referees, 17058.6ms
# Speed: 48.9ms preprocess, 17058.6ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 3
#
# 0: 384x640 1 ball, 14 players, 2 referees, 11870.0ms
# Speed: 14.4ms preprocess, 11870.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 4
#
# 0: 384x640 1 ball, 16 players, 2 referees, 12924.9ms
# Speed: 49.4ms preprocess, 12924.9ms inference, 324.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 5
#
# 0: 384x640 15 players, 2 referees, 15211.5ms
# Speed: 27.1ms preprocess, 15211.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 6
#
# 0: 384x640 15 players, 1 referee, 9223.1ms
# Speed: 21.0ms preprocess, 9223.1ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 7
#
# 0: 384x640 1 ball, 16 players, 1 referee, 9331.7ms
# Speed: 8.5ms preprocess, 9331.7ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 8
#
# 0: 384x640 1 ball, 15 players, 2 referees, 9567.6ms
# Speed: 8.9ms preprocess, 9567.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 9
#
# 0: 384x640 1 ball, 15 players, 2 referees, 10002.2ms
# Speed: 14.6ms preprocess, 10002.2ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 10
#
# 0: 384x640 1 ball, 15 players, 2 referees, 12823.9ms
# Speed: 15.1ms preprocess, 12823.9ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 11
#
# 0: 384x640 1 ball, 13 players, 2 referees, 12971.4ms
# Speed: 9.1ms preprocess, 12971.4ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 12
#
# 0: 384x640 14 players, 2 referees, 10340.7ms
# Speed: 8.4ms preprocess, 10340.7ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 13
#
# 0: 384x640 14 players, 2 referees, 11853.7ms
# Speed: 13.6ms preprocess, 11853.7ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 14
#
# 0: 384x640 19 players, 2 referees, 10609.5ms
# Speed: 7.9ms preprocess, 10609.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 15
#
# 0: 384x640 14 players, 2 referees, 12354.2ms
# Speed: 8.3ms preprocess, 12354.2ms inference, 12.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 16
#
# 0: 384x640 15 players, 2 referees, 11091.0ms
# Speed: 10.8ms preprocess, 11091.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 17
#
# 0: 384x640 15 players, 2 referees, 22231.0ms
# Speed: 11.0ms preprocess, 22231.0ms inference, 98.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 18
#
# 0: 384x640 15 players, 2 referees, 13371.9ms
# Speed: 59.9ms preprocess, 13371.9ms inference, 79.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 19
#
# 0: 384x640 14 players, 1 referee, 14323.0ms
# Speed: 16.0ms preprocess, 14323.0ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 20
#
# 0: 384x640 14 players, 4 referees, 20246.7ms
# Speed: 7.9ms preprocess, 20246.7ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 21
#
# 0: 384x640 14 players, 3 referees, 14217.6ms
# Speed: 25.1ms preprocess, 14217.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 22
#
# 0: 384x640 14 players, 3 referees, 12267.8ms
# Speed: 22.9ms preprocess, 12267.8ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 23
#
# 0: 384x640 14 players, 2 referees, 15383.1ms
# Speed: 18.0ms preprocess, 15383.1ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 24
#
# 0: 384x640 14 players, 3 referees, 12244.0ms
# Speed: 12.4ms preprocess, 12244.0ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 25
#
# 0: 384x640 14 players, 3 referees, 11177.9ms
# Speed: 10.4ms preprocess, 11177.9ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 26
#
# 0: 384x640 1 ball, 13 players, 2 referees, 10503.2ms
# Speed: 7.9ms preprocess, 10503.2ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 27
#
# 0: 384x640 2 balls, 13 players, 2 referees, 11180.7ms
# Speed: 21.1ms preprocess, 11180.7ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 28
#
# 0: 384x640 2 balls, 16 players, 2 referees, 12608.7ms
# Speed: 8.4ms preprocess, 12608.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 29
#
# 0: 384x640 2 balls, 15 players, 2 referees, 9196.8ms
# Speed: 11.2ms preprocess, 9196.8ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 30
#
# 0: 384x640 1 ball, 14 players, 2 referees, 9627.3ms
# Speed: 11.3ms preprocess, 9627.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 31
#
# 0: 384x640 1 ball, 14 players, 2 referees, 10586.3ms
# Speed: 9.1ms preprocess, 10586.3ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 32
#
# 0: 384x640 15 players, 2 referees, 10164.6ms
# Speed: 8.1ms preprocess, 10164.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 33
#
# 0: 384x640 14 players, 3 referees, 13148.3ms
# Speed: 7.4ms preprocess, 13148.3ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 34
#
# 0: 384x640 13 players, 3 referees, 11540.9ms
# Speed: 17.7ms preprocess, 11540.9ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 35
#
# 0: 384x640 1 ball, 15 players, 2 referees, 12092.2ms
# Speed: 8.3ms preprocess, 12092.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 36
#
# 0: 384x640 1 ball, 16 players, 2 referees, 11834.6ms
# Speed: 31.0ms preprocess, 11834.6ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 37
#
# 0: 384x640 1 ball, 16 players, 2 referees, 13605.6ms
# Speed: 7.5ms preprocess, 13605.6ms inference, 29.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 38
#
# 0: 384x640 1 ball, 18 players, 3 referees, 22419.8ms
# Speed: 12.8ms preprocess, 22419.8ms inference, 268.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 39
#
# 0: 384x640 1 ball, 17 players, 3 referees, 17337.8ms
# Speed: 35.4ms preprocess, 17337.8ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 40
#
# 0: 384x640 16 players, 3 referees, 15578.6ms
# Speed: 11.4ms preprocess, 15578.6ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 41
#
# 0: 384x640 14 players, 2 referees, 17908.8ms
# Speed: 13.0ms preprocess, 17908.8ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 42
#
# 0: 384x640 1 ball, 17 players, 2 referees, 14675.5ms
# Speed: 14.6ms preprocess, 14675.5ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 43
#
# 0: 384x640 1 ball, 18 players, 2 referees, 11817.6ms
# Speed: 71.5ms preprocess, 11817.6ms inference, 311.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 44
#
# 0: 384x640 1 ball, 17 players, 2 referees, 14637.6ms
# Speed: 9.5ms preprocess, 14637.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 45
#
# 0: 384x640 16 players, 3 referees, 15061.9ms
# Speed: 35.0ms preprocess, 15061.9ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 46
#
# 0: 384x640 1 ball, 17 players, 2 referees, 9670.0ms
# Speed: 17.1ms preprocess, 9670.0ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 47
#
# 0: 384x640 1 ball, 16 players, 2 referees, 12512.6ms
# Speed: 12.2ms preprocess, 12512.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 48
#
# 0: 384x640 16 players, 3 referees, 16734.2ms
# Speed: 56.1ms preprocess, 16734.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 49
#
# 0: 384x640 16 players, 2 referees, 11074.7ms
# Speed: 13.7ms preprocess, 11074.7ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 50
#
# 0: 384x640 17 players, 3 referees, 12567.5ms
# Speed: 11.3ms preprocess, 12567.5ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 51
#
# 0: 384x640 14 players, 3 referees, 9538.9ms
# Speed: 19.4ms preprocess, 9538.9ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 52
#
# 0: 384x640 16 players, 3 referees, 8988.7ms
# Speed: 11.9ms preprocess, 8988.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 53
#
# 0: 384x640 14 players, 4 referees, 10155.4ms
# Speed: 9.2ms preprocess, 10155.4ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 54
#
# 0: 384x640 17 players, 2 referees, 9024.0ms
# Speed: 8.3ms preprocess, 9024.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 55
#
# 0: 384x640 13 players, 2 referees, 9340.7ms
# Speed: 9.0ms preprocess, 9340.7ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 56
#
# 0: 384x640 13 players, 2 referees, 13281.4ms
# Speed: 14.4ms preprocess, 13281.4ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 57
#
# 0: 384x640 15 players, 2 referees, 8802.8ms
# Speed: 37.2ms preprocess, 8802.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 58
#
# 0: 384x640 15 players, 2 referees, 9211.6ms
# Speed: 8.4ms preprocess, 9211.6ms inference, 11.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 59
#
# 0: 384x640 1 ball, 14 players, 2 referees, 9349.4ms
# Speed: 22.9ms preprocess, 9349.4ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 60
#
# 0: 384x640 1 ball, 15 players, 2 referees, 9442.3ms
# Speed: 14.9ms preprocess, 9442.3ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 61
#
# 0: 384x640 1 ball, 15 players, 2 referees, 9257.2ms
# Speed: 7.9ms preprocess, 9257.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 62
#
# 0: 384x640 14 players, 2 referees, 11802.8ms
# Speed: 16.7ms preprocess, 11802.8ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 63
#
# 0: 384x640 1 ball, 14 players, 3 referees, 9492.5ms
# Speed: 15.9ms preprocess, 9492.5ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 64
#
# 0: 384x640 1 ball, 16 players, 4 referees, 10165.4ms
# Speed: 9.3ms preprocess, 10165.4ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 65
#
# 0: 384x640 1 ball, 14 players, 3 referees, 9439.0ms
# Speed: 11.5ms preprocess, 9439.0ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 66
#
# 0: 384x640 1 ball, 14 players, 4 referees, 9469.9ms
# Speed: 8.4ms preprocess, 9469.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 67
#
# 0: 384x640 1 ball, 14 players, 2 referees, 10160.1ms
# Speed: 12.9ms preprocess, 10160.1ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 68
#
# 0: 384x640 1 ball, 15 players, 2 referees, 12513.9ms
# Speed: 11.1ms preprocess, 12513.9ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 69
#
# 0: 384x640 1 ball, 14 players, 2 referees, 9871.3ms
# Speed: 13.0ms preprocess, 9871.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 70
#
# 0: 384x640 1 ball, 14 players, 2 referees, 15020.4ms
# Speed: 10.2ms preprocess, 15020.4ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 71
#
# 0: 384x640 1 ball, 15 players, 2 referees, 12829.8ms
# Speed: 8.2ms preprocess, 12829.8ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 72
#
# 0: 384x640 1 ball, 16 players, 2 referees, 11523.9ms
# Speed: 7.4ms preprocess, 11523.9ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 73
#
# 0: 384x640 1 ball, 15 players, 2 referees, 14201.7ms
# Speed: 11.3ms preprocess, 14201.7ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 74
#
# 0: 384x640 1 ball, 15 players, 2 referees, 15953.9ms
# Speed: 9.8ms preprocess, 15953.9ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 75
#
# 0: 384x640 1 ball, 15 players, 2 referees, 12204.4ms
# Speed: 22.0ms preprocess, 12204.4ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 76
#
# 0: 384x640 1 ball, 17 players, 1 referee, 12038.9ms
# Speed: 7.6ms preprocess, 12038.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 77
#
# 0: 384x640 17 players, 2 referees, 16106.3ms
# Speed: 12.4ms preprocess, 16106.3ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 78
#
# 0: 384x640 1 ball, 17 players, 2 referees, 12030.5ms
# Speed: 10.4ms preprocess, 12030.5ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 79
#
# 0: 384x640 1 ball, 14 players, 2 referees, 10268.6ms
# Speed: 8.9ms preprocess, 10268.6ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 80
#
# 0: 384x640 15 players, 2 referees, 11140.4ms
# Speed: 10.2ms preprocess, 11140.4ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 81
#
# 0: 384x640 14 players, 2 referees, 11218.4ms
# Speed: 17.7ms preprocess, 11218.4ms inference, 15.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 82
#
# 0: 384x640 14 players, 2 referees, 11404.2ms
# Speed: 10.2ms preprocess, 11404.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 83
#
# 0: 384x640 1 ball, 14 players, 2 referees, 12696.2ms
# Speed: 9.6ms preprocess, 12696.2ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 84
#
# 0: 384x640 14 players, 2 referees, 13500.2ms
# Speed: 13.6ms preprocess, 13500.2ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 85
#
# 0: 384x640 1 ball, 14 players, 2 referees, 10969.4ms
# Speed: 17.7ms preprocess, 10969.4ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 86
#
# 0: 384x640 1 ball, 15 players, 2 referees, 11578.2ms
# Speed: 11.3ms preprocess, 11578.2ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 87
#
# 0: 384x640 1 ball, 17 players, 2 referees, 11451.1ms
# Speed: 53.9ms preprocess, 11451.1ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 88
#
# 0: 384x640 1 ball, 16 players, 2 referees, 13403.3ms
# Speed: 17.2ms preprocess, 13403.3ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 89
#
# 0: 384x640 1 ball, 16 players, 1 referee, 10648.0ms
# Speed: 15.8ms preprocess, 10648.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 90
#
# 0: 384x640 1 ball, 18 players, 3 referees, 11518.9ms
# Speed: 11.1ms preprocess, 11518.9ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 91
#
# 0: 384x640 1 ball, 17 players, 2 referees, 11871.3ms
# Speed: 11.4ms preprocess, 11871.3ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 92
#
# 0: 384x640 1 ball, 18 players, 2 referees, 11684.9ms
# Speed: 12.2ms preprocess, 11684.9ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 93
#
# 0: 384x640 1 ball, 18 players, 2 referees, 16070.5ms
# Speed: 12.8ms preprocess, 16070.5ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 94
#
# 0: 384x640 1 ball, 16 players, 2 referees, 12317.8ms
# Speed: 37.4ms preprocess, 12317.8ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 95
#
# 0: 384x640 1 ball, 16 players, 2 referees, 14203.7ms
# Speed: 11.9ms preprocess, 14203.7ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 96
#
# 0: 384x640 1 ball, 18 players, 2 referees, 9904.0ms
# Speed: 9.5ms preprocess, 9904.0ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 97
#
# 0: 384x640 1 ball, 19 players, 3 referees, 10776.2ms
# Speed: 11.4ms preprocess, 10776.2ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 98
#
# 0: 384x640 1 ball, 16 players, 2 referees, 13187.9ms
# Speed: 10.4ms preprocess, 13187.9ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 99
#
# 0: 384x640 1 ball, 17 players, 2 referees, 15527.0ms
# Speed: 9.3ms preprocess, 15527.0ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 100
#
# 0: 384x640 1 ball, 17 players, 1 referee, 13331.6ms
# Speed: 75.0ms preprocess, 13331.6ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 101
#
# 0: 384x640 1 ball, 17 players, 2 referees, 11783.8ms
# Speed: 9.5ms preprocess, 11783.8ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 102
#
# 0: 384x640 1 ball, 16 players, 2 referees, 11336.2ms
# Speed: 9.5ms preprocess, 11336.2ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 103
#
# 0: 384x640 1 ball, 17 players, 2 referees, 11570.8ms
# Speed: 8.2ms preprocess, 11570.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 104
#
# 0: 384x640 1 ball, 17 players, 2 referees, 9897.2ms
# Speed: 8.5ms preprocess, 9897.2ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 105
#
# 0: 384x640 1 ball, 19 players, 2 referees, 12206.1ms
# Speed: 54.9ms preprocess, 12206.1ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 106
#
# 0: 384x640 1 ball, 15 players, 1 referee, 10038.8ms
# Speed: 13.5ms preprocess, 10038.8ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 107
#
# 0: 384x640 16 players, 10987.5ms
# Speed: 7.0ms preprocess, 10987.5ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 108
#
# 0: 384x640 1 ball, 16 players, 10845.0ms
# Speed: 13.7ms preprocess, 10845.0ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 109
#
# 0: 384x640 2 balls, 17 players, 13298.4ms
# Speed: 8.0ms preprocess, 13298.4ms inference, 14.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 110
#
# 0: 384x640 17 players, 1 referee, 11685.6ms
# Speed: 25.9ms preprocess, 11685.6ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 111
#
# 0: 384x640 19 players, 1 referee, 10193.3ms
# Speed: 12.4ms preprocess, 10193.3ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 112
#
# 0: 384x640 1 ball, 15 players, 2 referees, 12563.4ms
# Speed: 9.9ms preprocess, 12563.4ms inference, 17.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 113
#
# 0: 384x640 16 players, 1 referee, 11838.4ms
# Speed: 93.9ms preprocess, 11838.4ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 114
#
# 0: 384x640 15 players, 1 referee, 16600.7ms
# Speed: 16.4ms preprocess, 16600.7ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 115
#
# 0: 384x640 1 ball, 16 players, 1 referee, 13969.6ms
# Speed: 49.6ms preprocess, 13969.6ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 116
#
# 0: 384x640 16 players, 1 referee, 11090.3ms
# Speed: 25.1ms preprocess, 11090.3ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 117
#
# 0: 384x640 1 ball, 17 players, 1 referee, 11047.1ms
# Speed: 7.2ms preprocess, 11047.1ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 118
#
# 0: 384x640 14 players, 1 referee, 16227.9ms
# Speed: 15.7ms preprocess, 16227.9ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 119
#
# 0: 384x640 1 ball, 14 players, 1 referee, 15091.0ms
# Speed: 20.8ms preprocess, 15091.0ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 120
#
# 0: 384x640 1 ball, 15 players, 1 referee, 13868.9ms
# Speed: 10.3ms preprocess, 13868.9ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 121
#
# 0: 384x640 1 ball, 16 players, 1 referee, 15614.2ms
# Speed: 12.3ms preprocess, 15614.2ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 122
#
# 0: 384x640 16 players, 1 referee, 14676.5ms
# Speed: 13.3ms preprocess, 14676.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 123
#
# 0: 384x640 14 players, 1 referee, 20358.1ms
# Speed: 33.4ms preprocess, 20358.1ms inference, 11.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 124
#
# 0: 384x640 16 players, 2 referees, 11645.8ms
# Speed: 13.6ms preprocess, 11645.8ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 125
#
# 0: 384x640 15 players, 1 referee, 13467.7ms
# Speed: 8.0ms preprocess, 13467.7ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 126
#
# 0: 384x640 15 players, 1 referee, 20661.1ms
# Speed: 10.5ms preprocess, 20661.1ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 127
#
# 0: 384x640 1 ball, 15 players, 1 referee, 15595.0ms
# Speed: 68.9ms preprocess, 15595.0ms inference, 45.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 128
#
# 0: 384x640 1 ball, 14 players, 1 referee, 14524.2ms
# Speed: 13.1ms preprocess, 14524.2ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 129
#
# 0: 384x640 1 ball, 15 players, 1 referee, 12940.6ms
# Speed: 13.9ms preprocess, 12940.6ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 130
#
# 0: 384x640 1 ball, 15 players, 1 referee, 13772.5ms
# Speed: 10.4ms preprocess, 13772.5ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 131
#
# 0: 384x640 2 balls, 18 players, 1 referee, 16769.3ms
# Speed: 154.1ms preprocess, 16769.3ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 132
#
# 0: 384x640 1 ball, 15 players, 1 referee, 11769.5ms
# Speed: 11.3ms preprocess, 11769.5ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 133
#
# 0: 384x640 1 ball, 16 players, 1 referee, 11422.8ms
# Speed: 16.6ms preprocess, 11422.8ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 134
#
# 0: 384x640 15 players, 1 referee, 10519.3ms
# Speed: 7.9ms preprocess, 10519.3ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 135
#
# 0: 384x640 1 ball, 16 players, 1 referee, 12457.4ms
# Speed: 17.1ms preprocess, 12457.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 136
#
# 0: 384x640 1 ball, 14 players, 1 referee, 12591.6ms
# Speed: 8.5ms preprocess, 12591.6ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 137
#
# 0: 384x640 1 ball, 18 players, 1 referee, 11900.9ms
# Speed: 10.5ms preprocess, 11900.9ms inference, 17.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 138
#
# 0: 384x640 14 players, 1 referee, 11852.6ms
# Speed: 55.8ms preprocess, 11852.6ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 139
#
# 0: 384x640 16 players, 1 referee, 12084.7ms
# Speed: 9.9ms preprocess, 12084.7ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 140
#
# 0: 384x640 16 players, 1 referee, 11159.6ms
# Speed: 23.0ms preprocess, 11159.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 141
#
# 0: 384x640 15 players, 1 referee, 11587.7ms
# Speed: 9.7ms preprocess, 11587.7ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 142
#
# 0: 384x640 15 players, 1 referee, 11714.4ms
# Speed: 8.2ms preprocess, 11714.4ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 143
#
# 0: 384x640 1 ball, 13 players, 1 referee, 11829.5ms
# Speed: 9.7ms preprocess, 11829.5ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 144
#
# 0: 384x640 1 ball, 14 players, 2 referees, 11556.9ms
# Speed: 9.4ms preprocess, 11556.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 145
#
# 0: 384x640 1 ball, 15 players, 1 referee, 12595.3ms
# Speed: 12.1ms preprocess, 12595.3ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 146
#
# 0: 384x640 1 ball, 14 players, 1 referee, 12283.4ms
# Speed: 16.7ms preprocess, 12283.4ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 147
#
# 0: 384x640 13 players, 1 referee, 12893.8ms
# Speed: 14.8ms preprocess, 12893.8ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 148
#
# 0: 384x640 1 ball, 14 players, 1 referee, 10559.4ms
# Speed: 14.3ms preprocess, 10559.4ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 149
#
# 0: 384x640 1 ball, 13 players, 1 referee, 10950.4ms
# Speed: 10.7ms preprocess, 10950.4ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 150
#
# 0: 384x640 1 ball, 14 players, 1 referee, 11273.5ms
# Speed: 12.1ms preprocess, 11273.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 151
#
# 0: 384x640 1 ball, 13 players, 1 referee, 11879.0ms
# Speed: 9.6ms preprocess, 11879.0ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 152
#
# 0: 384x640 1 ball, 13 players, 1 referee, 13989.2ms
# Speed: 7.5ms preprocess, 13989.2ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 153
#
# 0: 384x640 1 ball, 14 players, 1 referee, 11330.0ms
# Speed: 9.9ms preprocess, 11330.0ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 154
#
# 0: 384x640 13 players, 1 referee, 12516.6ms
# Speed: 10.0ms preprocess, 12516.6ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 155
#
# 0: 384x640 1 ball, 12 players, 1 referee, 12436.6ms
# Speed: 14.6ms preprocess, 12436.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 156
#
# 0: 384x640 1 ball, 12 players, 1 referee, 11582.5ms
# Speed: 18.8ms preprocess, 11582.5ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 157
#
# 0: 384x640 12 players, 1 referee, 11956.9ms
# Speed: 10.2ms preprocess, 11956.9ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 158
#
# 0: 384x640 14 players, 1 referee, 10762.4ms
# Speed: 20.5ms preprocess, 10762.4ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 159
#
# 0: 384x640 15 players, 1 referee, 11791.1ms
# Speed: 9.4ms preprocess, 11791.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 160
#
# 0: 384x640 13 players, 1 referee, 11273.6ms
# Speed: 11.1ms preprocess, 11273.6ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 161
#
# 0: 384x640 12 players, 1 referee, 11540.8ms
# Speed: 17.6ms preprocess, 11540.8ms inference, 16.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 162
#
# 0: 384x640 12 players, 1 referee, 11360.2ms
# Speed: 46.0ms preprocess, 11360.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 163
#
# 0: 384x640 12 players, 1 referee, 11271.9ms
# Speed: 15.6ms preprocess, 11271.9ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 164
#
# 0: 384x640 12 players, 1 referee, 11498.5ms
# Speed: 10.6ms preprocess, 11498.5ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 165
#
# 0: 384x640 12 players, 1 referee, 11940.4ms
# Speed: 113.9ms preprocess, 11940.4ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 166
#
# 0: 384x640 1 ball, 13 players, 11472.6ms
# Speed: 9.5ms preprocess, 11472.6ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 167
#
# 0: 384x640 1 ball, 13 players, 11248.8ms
# Speed: 30.6ms preprocess, 11248.8ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 168
#
# 0: 384x640 1 ball, 13 players, 10222.4ms
# Speed: 12.6ms preprocess, 10222.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 169
#
# 0: 384x640 16 players, 1 referee, 13045.1ms
# Speed: 12.8ms preprocess, 13045.1ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 170
#
# 0: 384x640 13 players, 1 referee, 11097.7ms
# Speed: 10.7ms preprocess, 11097.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 171
#
# 0: 384x640 13 players, 1 referee, 11423.2ms
# Speed: 11.4ms preprocess, 11423.2ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 172
#
# 0: 384x640 13 players, 1 referee, 11123.2ms
# Speed: 10.2ms preprocess, 11123.2ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 173
#
# 0: 384x640 15 players, 11493.7ms
# Speed: 18.0ms preprocess, 11493.7ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 174
#
# 0: 384x640 14 players, 10441.7ms
# Speed: 12.7ms preprocess, 10441.7ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 175
#
# 0: 384x640 1 ball, 14 players, 11336.1ms
# Speed: 13.7ms preprocess, 11336.1ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 176
#
# 0: 384x640 13 players, 10691.6ms
# Speed: 14.9ms preprocess, 10691.6ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 177
#
# 0: 384x640 13 players, 1 referee, 11036.1ms
# Speed: 11.9ms preprocess, 11036.1ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 178
#
# 0: 384x640 2 balls, 11 players, 1 referee, 13028.9ms
# Speed: 14.7ms preprocess, 13028.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 179
#
# 0: 384x640 15 players, 1 referee, 12142.2ms
# Speed: 16.2ms preprocess, 12142.2ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 180
#
# 0: 384x640 12 players, 1 referee, 11096.1ms
# Speed: 12.0ms preprocess, 11096.1ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 181
#
# 0: 384x640 1 ball, 12 players, 1 referee, 12488.1ms
# Speed: 7.5ms preprocess, 12488.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 182
#
# 0: 384x640 14 players, 1 referee, 8924.2ms
# Speed: 10.1ms preprocess, 8924.2ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 183
#
# 0: 384x640 12 players, 8529.2ms
# Speed: 12.2ms preprocess, 8529.2ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 184
#
# 0: 384x640 12 players, 9676.5ms
# Speed: 7.1ms preprocess, 9676.5ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 185
#
# 0: 384x640 1 ball, 12 players, 9909.3ms
# Speed: 12.4ms preprocess, 9909.3ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 186
#
# 0: 384x640 1 ball, 12 players, 1 referee, 10244.1ms
# Speed: 31.3ms preprocess, 10244.1ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 187
#
# 0: 384x640 12 players, 1 referee, 9617.6ms
# Speed: 11.3ms preprocess, 9617.6ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 188
#
# 0: 384x640 1 ball, 11 players, 1 referee, 10142.6ms
# Speed: 10.5ms preprocess, 10142.6ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 189
#
# 0: 384x640 1 ball, 12 players, 1 referee, 10168.5ms
# Speed: 27.7ms preprocess, 10168.5ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 190
#
# 0: 384x640 1 ball, 12 players, 9983.4ms
# Speed: 9.5ms preprocess, 9983.4ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 191
#
# 0: 384x640 1 ball, 15 players, 10490.3ms
# Speed: 17.2ms preprocess, 10490.3ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 192
#
# 0: 384x640 2 balls, 14 players, 8788.8ms
# Speed: 32.8ms preprocess, 8788.8ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 193
#
# 0: 384x640 14 players, 10044.4ms
# Speed: 9.2ms preprocess, 10044.4ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 194
#
# 0: 384x640 13 players, 9718.6ms
# Speed: 9.3ms preprocess, 9718.6ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 195
#
# 0: 384x640 18 players, 9155.1ms
# Speed: 10.8ms preprocess, 9155.1ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 196
#
# 0: 384x640 14 players, 8494.8ms
# Speed: 14.1ms preprocess, 8494.8ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 197
#
# 0: 384x640 1 ball, 17 players, 9764.2ms
# Speed: 12.0ms preprocess, 9764.2ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 198
#
# 0: 384x640 16 players, 9517.4ms
# Speed: 11.7ms preprocess, 9517.4ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 199
#
# 0: 384x640 1 ball, 14 players, 10504.8ms
# Speed: 15.6ms preprocess, 10504.8ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 200
#
# 0: 384x640 1 ball, 17 players, 10414.7ms
# Speed: 7.5ms preprocess, 10414.7ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 201
#
# 0: 384x640 1 ball, 15 players, 9901.6ms
# Speed: 18.3ms preprocess, 9901.6ms inference, 11.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 202
#
# 0: 384x640 1 ball, 14 players, 9141.9ms
# Speed: 16.9ms preprocess, 9141.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 203
#
# 0: 384x640 2 balls, 13 players, 9206.5ms
# Speed: 7.6ms preprocess, 9206.5ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 204
#
# 0: 384x640 14 players, 8726.1ms
# Speed: 7.8ms preprocess, 8726.1ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 205
#
# 0: 384x640 14 players, 9649.3ms
# Speed: 9.8ms preprocess, 9649.3ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 206
#
# 0: 384x640 13 players, 9387.9ms
# Speed: 11.3ms preprocess, 9387.9ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 207
#
# 0: 384x640 1 ball, 15 players, 8658.2ms
# Speed: 9.6ms preprocess, 8658.2ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 208
#
# 0: 384x640 1 ball, 13 players, 9214.2ms
# Speed: 8.2ms preprocess, 9214.2ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 209
#
# 0: 384x640 13 players, 9150.2ms
# Speed: 24.6ms preprocess, 9150.2ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 210
#
# 0: 384x640 12 players, 10008.0ms
# Speed: 9.2ms preprocess, 10008.0ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 211
#
# 0: 384x640 1 ball, 12 players, 9715.8ms
# Speed: 26.0ms preprocess, 9715.8ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 212
#
# 0: 384x640 1 ball, 12 players, 11031.7ms
# Speed: 11.4ms preprocess, 11031.7ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 213
#
# 0: 384x640 2 balls, 10 players, 9073.0ms
# Speed: 9.8ms preprocess, 9073.0ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 214
#
# 0: 384x640 1 ball, 11 players, 10582.7ms
# Speed: 16.3ms preprocess, 10582.7ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 215
#
# 0: 384x640 1 ball, 15 players, 10175.4ms
# Speed: 21.7ms preprocess, 10175.4ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 216
#
# 0: 384x640 11 players, 9744.1ms
# Speed: 15.7ms preprocess, 9744.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 217
#
# 0: 384x640 10 players, 8896.4ms
# Speed: 96.9ms preprocess, 8896.4ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 218
#
# 0: 384x640 12 players, 9442.1ms
# Speed: 7.0ms preprocess, 9442.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 219
#
# 0: 384x640 9 players, 8804.5ms
# Speed: 12.0ms preprocess, 8804.5ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 220
#
# 0: 384x640 8 players, 8834.4ms
# Speed: 24.4ms preprocess, 8834.4ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 221
#
# 0: 384x640 8 players, 8555.6ms
# Speed: 7.6ms preprocess, 8555.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 222
#
# 0: 384x640 10 players, 9997.8ms
# Speed: 14.5ms preprocess, 9997.8ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 223
#
# 0: 384x640 1 ball, 10 players, 9533.8ms
# Speed: 10.5ms preprocess, 9533.8ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 224
#
# 0: 384x640 1 ball, 9 players, 9181.4ms
# Speed: 11.8ms preprocess, 9181.4ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 225
#
# 0: 384x640 2 balls, 9 players, 9912.7ms
# Speed: 8.8ms preprocess, 9912.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 226
#
# 0: 384x640 1 ball, 1 goalkeeper, 8 players, 10661.0ms
# Speed: 10.6ms preprocess, 10661.0ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 227
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 9745.4ms
# Speed: 9.5ms preprocess, 9745.4ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 228
#
# 0: 384x640 2 balls, 1 goalkeeper, 11 players, 9124.3ms
# Speed: 20.3ms preprocess, 9124.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 229
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 9464.7ms
# Speed: 12.1ms preprocess, 9464.7ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 230
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 9092.6ms
# Speed: 16.4ms preprocess, 9092.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 231
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 9256.5ms
# Speed: 11.7ms preprocess, 9256.5ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 232
#
# 0: 384x640 3 balls, 8 players, 9153.7ms
# Speed: 14.9ms preprocess, 9153.7ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 233
#
# 0: 384x640 1 goalkeeper, 8 players, 8919.2ms
# Speed: 24.9ms preprocess, 8919.2ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 234
#
# 0: 384x640 11 players, 8906.1ms
# Speed: 8.0ms preprocess, 8906.1ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 235
#
# 0: 384x640 1 ball, 11 players, 9449.5ms
# Speed: 10.2ms preprocess, 9449.5ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 236
#
# 0: 384x640 1 ball, 9 players, 8910.0ms
# Speed: 11.9ms preprocess, 8910.0ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 237
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 9774.4ms
# Speed: 24.2ms preprocess, 9774.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 238
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 10349.5ms
# Speed: 10.7ms preprocess, 10349.5ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 239
#
# 0: 384x640 1 ball, 1 goalkeeper, 8 players, 9692.7ms
# Speed: 10.5ms preprocess, 9692.7ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 240
#
# 0: 384x640 1 goalkeeper, 7 players, 9623.6ms
# Speed: 13.1ms preprocess, 9623.6ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 241
#
# 0: 384x640 1 goalkeeper, 7 players, 9823.5ms
# Speed: 29.4ms preprocess, 9823.5ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 242
#
# 0: 384x640 1 goalkeeper, 9 players, 8756.2ms
# Speed: 28.8ms preprocess, 8756.2ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 243
#
# 0: 384x640 1 goalkeeper, 8 players, 9474.0ms
# Speed: 18.7ms preprocess, 9474.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 244
#
# 0: 384x640 2 balls, 1 goalkeeper, 9 players, 8455.0ms
# Speed: 7.8ms preprocess, 8455.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 245
#
# 0: 384x640 1 goalkeeper, 8 players, 9356.2ms
# Speed: 21.6ms preprocess, 9356.2ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 246
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 8804.5ms
# Speed: 7.5ms preprocess, 8804.5ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 247
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 8649.8ms
# Speed: 14.0ms preprocess, 8649.8ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 248
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 9021.2ms
# Speed: 12.5ms preprocess, 9021.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 249
#
# 0: 384x640 2 balls, 1 goalkeeper, 9 players, 9284.6ms
# Speed: 35.1ms preprocess, 9284.6ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 250
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 9510.5ms
# Speed: 19.8ms preprocess, 9510.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 251
#
# 0: 384x640 1 goalkeeper, 10 players, 9194.6ms
# Speed: 10.8ms preprocess, 9194.6ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 252
#
# 0: 384x640 10 players, 10235.7ms
# Speed: 26.1ms preprocess, 10235.7ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 253
#
# 0: 384x640 10 players, 11181.4ms
# Speed: 28.7ms preprocess, 11181.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 254
#
# 0: 384x640 11 players, 11332.4ms
# Speed: 62.2ms preprocess, 11332.4ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 255
#
# 0: 384x640 1 goalkeeper, 12 players, 9477.3ms
# Speed: 18.8ms preprocess, 9477.3ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 256
#
# 0: 384x640 1 goalkeeper, 10 players, 9685.9ms
# Speed: 10.5ms preprocess, 9685.9ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 257
#
# 0: 384x640 1 goalkeeper, 10 players, 17685.3ms
# Speed: 9.9ms preprocess, 17685.3ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 258
#
# 0: 384x640 1 goalkeeper, 11 players, 16953.4ms
# Speed: 42.6ms preprocess, 16953.4ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 259
#
# 0: 384x640 1 goalkeeper, 9 players, 14002.1ms
# Speed: 23.7ms preprocess, 14002.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 260
#
# 0: 384x640 1 goalkeeper, 8 players, 13291.3ms
# Speed: 114.0ms preprocess, 13291.3ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 261
#
# 0: 384x640 1 goalkeeper, 9 players, 16924.4ms
# Speed: 27.1ms preprocess, 16924.4ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 262
#
# 0: 384x640 1 goalkeeper, 9 players, 11361.7ms
# Speed: 17.4ms preprocess, 11361.7ms inference, 15.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 263
#
# 0: 384x640 1 goalkeeper, 9 players, 10589.0ms
# Speed: 14.9ms preprocess, 10589.0ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 264
#
# 0: 384x640 12 players, 11452.5ms
# Speed: 10.1ms preprocess, 11452.5ms inference, 50.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 265
#
# 0: 384x640 11 players, 22610.0ms
# Speed: 64.1ms preprocess, 22610.0ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 266
#
# 0: 384x640 1 goalkeeper, 11 players, 16337.4ms
# Speed: 116.2ms preprocess, 16337.4ms inference, 60.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 267
#
# 0: 384x640 13 players, 10586.2ms
# Speed: 43.0ms preprocess, 10586.2ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 268
#
# 0: 384x640 1 goalkeeper, 11 players, 11778.2ms
# Speed: 28.4ms preprocess, 11778.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 269
#
# 0: 384x640 1 goalkeeper, 8 players, 15417.1ms
# Speed: 46.6ms preprocess, 15417.1ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 270
#
# 0: 384x640 1 goalkeeper, 12 players, 11692.6ms
# Speed: 34.9ms preprocess, 11692.6ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 271
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 13087.0ms
# Speed: 38.3ms preprocess, 13087.0ms inference, 96.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 272
#
# 0: 384x640 8 players, 11385.1ms
# Speed: 22.4ms preprocess, 11385.1ms inference, 20.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 273
#
# 0: 384x640 1 ball, 11 players, 10943.1ms
# Speed: 116.9ms preprocess, 10943.1ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 274
#
# 0: 384x640 1 ball, 9 players, 9670.6ms
# Speed: 13.2ms preprocess, 9670.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 275
#
# 0: 384x640 10 players, 10553.8ms
# Speed: 22.9ms preprocess, 10553.8ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 276
#
# 0: 384x640 1 ball, 10 players, 11457.7ms
# Speed: 30.4ms preprocess, 11457.7ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 277
#
# 0: 384x640 1 ball, 10 players, 11373.0ms
# Speed: 22.4ms preprocess, 11373.0ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 278
#
# 0: 384x640 11 players, 11426.5ms
# Speed: 40.0ms preprocess, 11426.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 279
#
# 0: 384x640 14 players, 11924.1ms
# Speed: 11.4ms preprocess, 11924.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 280
#
# 0: 384x640 14 players, 13536.6ms
# Speed: 29.9ms preprocess, 13536.6ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 281
#
# 0: 384x640 15 players, 12281.4ms
# Speed: 44.4ms preprocess, 12281.4ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 282
#
# 0: 384x640 11 players, 11364.6ms
# Speed: 17.1ms preprocess, 11364.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 283
#
# 0: 384x640 12 players, 10923.5ms
# Speed: 38.8ms preprocess, 10923.5ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 284
#
# 0: 384x640 1 ball, 12 players, 10924.4ms
# Speed: 23.3ms preprocess, 10924.4ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 285
#
# 0: 384x640 18 players, 10518.2ms
# Speed: 14.5ms preprocess, 10518.2ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 286
#
# 0: 384x640 1 goalkeeper, 15 players, 11779.9ms
# Speed: 20.2ms preprocess, 11779.9ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 287
#
# 0: 384x640 1 goalkeeper, 13 players, 10407.6ms
# Speed: 9.4ms preprocess, 10407.6ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 288
#
# 0: 384x640 1 goalkeeper, 12 players, 11336.0ms
# Speed: 11.8ms preprocess, 11336.0ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 289
#
# 0: 384x640 1 goalkeeper, 9 players, 11268.6ms
# Speed: 78.2ms preprocess, 11268.6ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 290
#
# 0: 384x640 15 players, 11106.0ms
# Speed: 13.4ms preprocess, 11106.0ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 291
#
# 0: 384x640 14 players, 11900.0ms
# Speed: 34.8ms preprocess, 11900.0ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 292
#
# 0: 384x640 13 players, 10829.2ms
# Speed: 17.2ms preprocess, 10829.2ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 293
#
# 0: 384x640 14 players, 11129.0ms
# Speed: 65.4ms preprocess, 11129.0ms inference, 15.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 294
#
# 0: 384x640 18 players, 10480.4ms
# Speed: 26.0ms preprocess, 10480.4ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 295
#
# 0: 384x640 16 players, 10935.0ms
# Speed: 24.0ms preprocess, 10935.0ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 296
#
# 0: 384x640 1 goalkeeper, 16 players, 11310.9ms
# Speed: 18.5ms preprocess, 11310.9ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 297
#
# 0: 384x640 1 goalkeeper, 15 players, 10719.2ms
# Speed: 16.8ms preprocess, 10719.2ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 298
#
# 0: 384x640 1 goalkeeper, 15 players, 10306.1ms
# Speed: 25.4ms preprocess, 10306.1ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 299
#
# 0: 384x640 1 goalkeeper, 15 players, 11702.8ms
# Speed: 31.6ms preprocess, 11702.8ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 300
#
# 0: 384x640 1 goalkeeper, 13 players, 10922.0ms
# Speed: 16.8ms preprocess, 10922.0ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 301
#
# 0: 384x640 1 goalkeeper, 13 players, 11287.4ms
# Speed: 23.3ms preprocess, 11287.4ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 302
#
# 0: 384x640 1 goalkeeper, 15 players, 11266.8ms
# Speed: 10.2ms preprocess, 11266.8ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 303
#
# 0: 384x640 1 goalkeeper, 14 players, 12998.6ms
# Speed: 9.7ms preprocess, 12998.6ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 304
#
# 0: 384x640 1 goalkeeper, 19 players, 10551.1ms
# Speed: 25.5ms preprocess, 10551.1ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 305
#
# 0: 384x640 1 goalkeeper, 18 players, 10574.2ms
# Speed: 28.0ms preprocess, 10574.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 306
#
# 0: 384x640 2 goalkeepers, 15 players, 10859.1ms
# Speed: 12.8ms preprocess, 10859.1ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 307
#
# 0: 384x640 16 players, 12230.5ms
# Speed: 26.7ms preprocess, 12230.5ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 308
#
# 0: 384x640 1 goalkeeper, 17 players, 10236.2ms
# Speed: 11.8ms preprocess, 10236.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 309
#
# 0: 384x640 1 goalkeeper, 15 players, 11787.3ms
# Speed: 27.4ms preprocess, 11787.3ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 310
#
# 0: 384x640 1 goalkeeper, 19 players, 12078.6ms
# Speed: 43.7ms preprocess, 12078.6ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 311
#
# 0: 384x640 2 goalkeepers, 15 players, 12109.5ms
# Speed: 19.3ms preprocess, 12109.5ms inference, 15.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 312
#
# 0: 384x640 1 goalkeeper, 16 players, 12320.1ms
# Speed: 53.3ms preprocess, 12320.1ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 313
#
# 0: 384x640 1 goalkeeper, 13 players, 11977.7ms
# Speed: 13.5ms preprocess, 11977.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 314
#
# 0: 384x640 1 goalkeeper, 16 players, 11055.2ms
# Speed: 145.7ms preprocess, 11055.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 315
#
# 0: 384x640 1 goalkeeper, 12 players, 12424.1ms
# Speed: 18.8ms preprocess, 12424.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 316
#
# 0: 384x640 1 goalkeeper, 14 players, 15368.1ms
# Speed: 9.1ms preprocess, 15368.1ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 317
#
# 0: 384x640 1 ball, 1 goalkeeper, 16 players, 10610.0ms
# Speed: 48.8ms preprocess, 10610.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 318
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 10976.7ms
# Speed: 20.2ms preprocess, 10976.7ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 319
#
# 0: 384x640 12 players, 10841.3ms
# Speed: 43.0ms preprocess, 10841.3ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 320
#
# 0: 384x640 1 ball, 14 players, 12486.4ms
# Speed: 38.3ms preprocess, 12486.4ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 321
#
# 0: 384x640 12 players, 13098.4ms
# Speed: 15.7ms preprocess, 13098.4ms inference, 20.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 322
#
# 0: 384x640 14 players, 11699.8ms
# Speed: 69.8ms preprocess, 11699.8ms inference, 16.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 323
#
# 0: 384x640 13 players, 11766.3ms
# Speed: 34.9ms preprocess, 11766.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 324
#
# 0: 384x640 1 ball, 14 players, 11038.0ms
# Speed: 34.8ms preprocess, 11038.0ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 325
#
# 0: 384x640 1 ball, 14 players, 11355.9ms
# Speed: 10.1ms preprocess, 11355.9ms inference, 17.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 326
#
# 0: 384x640 1 ball, 17 players, 11155.6ms
# Speed: 110.2ms preprocess, 11155.6ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 327
#
# 0: 384x640 1 ball, 11 players, 11301.7ms
# Speed: 15.6ms preprocess, 11301.7ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 328
#
# 0: 384x640 12 players, 11534.5ms
# Speed: 21.3ms preprocess, 11534.5ms inference, 14.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 329
#
# 0: 384x640 12 players, 12679.6ms
# Speed: 38.4ms preprocess, 12679.6ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 330
#
# 0: 384x640 12 players, 11961.2ms
# Speed: 19.4ms preprocess, 11961.2ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 331
#
# 0: 384x640 11 players, 11397.3ms
# Speed: 64.9ms preprocess, 11397.3ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 332
#
# 0: 384x640 14 players, 12840.3ms
# Speed: 30.1ms preprocess, 12840.3ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 333
#
# 0: 384x640 11 players, 11916.4ms
# Speed: 22.1ms preprocess, 11916.4ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 334
#
# 0: 384x640 8 players, 11550.5ms
# Speed: 65.1ms preprocess, 11550.5ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 335
#
# 0: 384x640 1 ball, 9 players, 12384.2ms
# Speed: 35.8ms preprocess, 12384.2ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 336
#
# 0: 384x640 11 players, 12259.6ms
# Speed: 32.1ms preprocess, 12259.6ms inference, 31.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 337
#
# 0: 384x640 9 players, 14811.0ms
# Speed: 132.2ms preprocess, 14811.0ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 338
#
# 0: 384x640 14 players, 10802.8ms
# Speed: 40.6ms preprocess, 10802.8ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 339
#
# 0: 384x640 14 players, 11981.0ms
# Speed: 27.6ms preprocess, 11981.0ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 340
#
# 0: 384x640 14 players, 11824.4ms
# Speed: 20.1ms preprocess, 11824.4ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 341
#
# 0: 384x640 13 players, 10208.5ms
# Speed: 10.2ms preprocess, 10208.5ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 342
#
# 0: 384x640 14 players, 11346.5ms
# Speed: 39.2ms preprocess, 11346.5ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 343
#
# 0: 384x640 15 players, 12442.1ms
# Speed: 7.6ms preprocess, 12442.1ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 344
#
# 0: 384x640 15 players, 12924.7ms
# Speed: 7.3ms preprocess, 12924.7ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 345
#
# 0: 384x640 13 players, 12850.5ms
# Speed: 12.4ms preprocess, 12850.5ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 346
#
# 0: 384x640 13 players, 12427.4ms
# Speed: 7.9ms preprocess, 12427.4ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 347
#
# 0: 384x640 15 players, 12213.9ms
# Speed: 39.4ms preprocess, 12213.9ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 348
#
# 0: 384x640 13 players, 11857.3ms
# Speed: 15.3ms preprocess, 11857.3ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 349
#
# 0: 384x640 13 players, 11487.7ms
# Speed: 22.8ms preprocess, 11487.7ms inference, 11.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 350
#
# 0: 384x640 14 players, 11448.4ms
# Speed: 58.2ms preprocess, 11448.4ms inference, 11.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 351
#
# 0: 384x640 16 players, 13013.7ms
# Speed: 21.3ms preprocess, 13013.7ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 352
#
# 0: 384x640 16 players, 11948.3ms
# Speed: 97.7ms preprocess, 11948.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 353
#
# 0: 384x640 16 players, 11962.4ms
# Speed: 9.3ms preprocess, 11962.4ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 354
#
# 0: 384x640 19 players, 11641.5ms
# Speed: 10.0ms preprocess, 11641.5ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 355
#
# 0: 384x640 13 players, 11386.6ms
# Speed: 38.1ms preprocess, 11386.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 356
#
# 0: 384x640 15 players, 11540.2ms
# Speed: 9.7ms preprocess, 11540.2ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 357
#
# 0: 384x640 13 players, 11699.7ms
# Speed: 9.9ms preprocess, 11699.7ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 358
#
# 0: 384x640 12 players, 11847.0ms
# Speed: 46.5ms preprocess, 11847.0ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 359
#
# 0: 384x640 15 players, 11844.4ms
# Speed: 45.0ms preprocess, 11844.4ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 360
#
# 0: 384x640 15 players, 10348.2ms
# Speed: 30.2ms preprocess, 10348.2ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 361
#
# 0: 384x640 13 players, 11458.4ms
# Speed: 24.1ms preprocess, 11458.4ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 362
#
# 0: 384x640 13 players, 11107.4ms
# Speed: 12.9ms preprocess, 11107.4ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 363
#
# 0: 384x640 12 players, 19625.7ms
# Speed: 29.5ms preprocess, 19625.7ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 364
#
# 0: 384x640 12 players, 24368.8ms
# Speed: 118.3ms preprocess, 24368.8ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 365
#
# 0: 384x640 13 players, 23995.3ms
# Speed: 67.8ms preprocess, 23995.3ms inference, 25.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 366
#
# 0: 384x640 14 players, 19496.1ms
# Speed: 158.0ms preprocess, 19496.1ms inference, 26.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 367
#
# 0: 384x640 15 players, 17857.6ms
# Speed: 134.3ms preprocess, 17857.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 368
#
# 0: 384x640 15 players, 14689.8ms
# Speed: 29.1ms preprocess, 14689.8ms inference, 41.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 369
#
# 0: 384x640 12 players, 22063.6ms
# Speed: 229.2ms preprocess, 22063.6ms inference, 29.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 370
#
# 0: 384x640 (no detections), 20802.3ms
# Speed: 118.1ms preprocess, 20802.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 371
#
# 0: 384x640 1 player, 22655.2ms
# Speed: 42.6ms preprocess, 22655.2ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 372
#
# 0: 384x640 1 player, 21011.8ms
# Speed: 7.6ms preprocess, 21011.8ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 373
#
# 0: 384x640 1 player, 27364.3ms
# Speed: 111.5ms preprocess, 27364.3ms inference, 48.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processed frame 374

# %%
with open("player_tracks.json", "w") as f:
    json.dump(tracking_output, f, indent=2)

print(f"Saved tracking data for {len(tracking_output)} detections.")
# Out:
# Saved tracking data for 4780 detections.
